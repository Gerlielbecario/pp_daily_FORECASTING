# %%
import os
folder = '/home/fernando.huaranca/datos/DATOS_REFORECAST/apcp_sfc'

FileS = os.listdir(folder)

FileS = FileS[0:3]
FileS
# Out:
# ['apcp_sfc_2000013000_c00.grib2.923a8.idx',
#  'apcp_sfc_2010111600_c00.grib2',
#  'apcp_sfc_2000043000_c00.grib2']

# %%
#Este es un codigo al que se le ingresa una lista de archivos y devuelve
#matrices en formato .npz que almacenan la precipitacion diaria 
#del los archivos


#########Librerias##################
from funcion_extrae_tiempos import extrae_tiempos

import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import os 
import pandas as pd


#------CARGAR ARCHIVOS------------------

#Carpeta donde se encuentra el archivo


#-------LIMITES PARA EL SUSBSET-----------



#-------BUCLE PARA PROCESAR CADA ARCHIVO-----------------------
folder = '/home/fernando.huaranca/datos/DATOS_REFORECAST/apcp_sfc'

path = os.path.join('apcp_sfc_2000013000_c00.grib2.923a8.idx')



try:
    #Abrimos el dataset
    ds = xr.open_dataset(path)

    print('Comienza la extraccion de variables')

    #Extraigo el array de Total Precipitation
    var = ds.tp.values

    #Extrae indices de steps
    idx_steps = extrae_tiempos(ds)

    #Extraigo latitudes y longitudes

    lat = ds.tp.latitude.values
    lon = ds.tp.longitude.values

    #Cerramos dataset
    ds.close()

except Exception as e:
        print(f'Error al procesar el archivo')

print('Se extrajo correctamente las variables del file: ')
# Out:
# /home/fernando.huaranca/datos/DATOS_REFORECAST/apcp_sfc/apcp_sfc_2009102400_c00.grib2
# <class 'xarray.core.dataset.Dataset'>
# Error al procesar el archivo
# Se extrajo correctamente las variables del file:

# %%
#Este es un codigo al que se le ingresa una lista de archivos y devuelve
#matrices en formato .npz que almacenan la precipitacion diaria 
#del los archivos


#########Librerias##################
from funcion_extrae_tiempos import extrae_tiempos

import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import os 
import pandas as pd


#------CARGAR ARCHIVOS------------------

#Carpeta donde se encuentra el archivo


#-------LIMITES PARA EL SUSBSET-----------



#-------BUCLE PARA PROCESAR CADA ARCHIVO-----------------------
folder = '/home/fernando.huaranca/datos/DATOS_REFORECAST/apcp_sfc'

path = os.path.join('apcp_sfc_2000013000_c00.grib2.923a8.idx')



try:
    #Abrimos el dataset
    ds = xr.open_dataset(path)

    print('Comienza la extraccion de variables')

    #Extraigo el array de Total Precipitation
    var = ds.tp.values

    #Extrae indices de steps
    idx_steps = extrae_tiempos(ds)

    #Extraigo latitudes y longitudes

    lat = ds.tp.latitude.values
    lon = ds.tp.longitude.values

    #Cerramos dataset
    ds.close()

except Exception as e:
        print(f'Error al procesar el archivo')

print('Se extrajo correctamente las variables del file: ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
#----SUBSET
#-------LIMITES PARA EL SUSBSET-----------

#Region de sudamerica

ini_lon=260.0
end_lon=330.0
ini_lat=-65.0
end_lat=15.0   
#latitudes
lat_index = np.flatnonzero((lat <end_lat) & (lat > ini_lat))
lat = lat[lat_index]

#longitudes
lon_index = np.flatnonzero((lon > ini_lon) & (lon < end_lon))

lon = lon[lon_index]

# %%
#Tiempos para el dia N  
row = lat.shape[0]
col = lon.shape[0]

#print('Comienza la creacion de las 10 matrices de pp acumulada para:',file)
        
for dia in range(idx_steps.shape[0]):

    #Inicializo matriz de pp acumulada
    pp = np.zeros([row,col])

    #Selecciono los indices de steps del dia N
    DiaN = idx_steps[dia,1:]

    name_file = f'{idx_steps[dia, 0]}' 

    print(f'Leyendo archivo {name_file}')

    #Genero una matriz que almacena la precipitacion acumulada
    #por dia
    for tiempo in DiaN:
        pp = np.round(var[tiempo,lat_index[0]:lat_index[-1]+1,lon_index[0]:lon_index[-1]+1] + pp,3)
            
       # print('Matrices del file ',file,' generadas correctamente')

    # Ruta completa del archivo donde guardar los datos
    out_path = f'/home/fernando.huaranca/test_forecast/output_matrices/{name_file}.npz'


    # Guardar los arreglos en el archivo

    np.savez(out_path,pp_daily = pp, latitudes = lat,longitudes = lon,name = name_file)

    print('Finalizado')
# Out:
# Leyendo archivo 16-11-2010
# Finalizado
# Leyendo archivo 17-11-2010
# Finalizado
# Leyendo archivo 18-11-2010
# Finalizado
# Leyendo archivo 19-11-2010
# Finalizado
# Leyendo archivo 20-11-2010
# Finalizado
# Leyendo archivo 21-11-2010
# Finalizado
# Leyendo archivo 22-11-2010
# Finalizado
# Leyendo archivo 23-11-2010
# Finalizado
# Leyendo archivo 24-11-2010
# Finalizado
# Leyendo archivo 25-11-2010
# Finalizado

# %%
len(Files)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 len(Files)
#
# NameError: name 'Files' is not defined

# %%
#Este es un codigo al que se le ingresa una lista de archivos y devuelve
#matrices en formato .npz que almacenan la precipitacion diaria 
#del los archivos


#########Librerias##################
from funcion_extrae_tiempos import extrae_tiempos

import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import os 
import pandas as pd


#------CARGAR ARCHIVOS------------------

#Carpeta donde se encuentra el archivo
folder = '/home/fernando.huaranca/datos/DATOS_REFORECAST/apcp_sfc'

FileS = os.listdir(folder)

FileS = FileS[2:3]
print(FileS)
print('Lista de archivos cargada')



#-------LIMITES PARA EL SUSBSET-----------

#Region de sudamerica

ini_lon=260.0
end_lon=330.0
ini_lat=-65.0
end_lat=15.0

#Lista para almacenar archivos erroneos

fallidos = []


#-------BUCLE PARA PROCESAR CADA ARCHIVO-----------------------

for file in FileS:


    #Ruta del archivo
    path = os.path.join(folder,file)

    print('Leyendo archivo: ',file)
    try:

        #Abrimos el dataset
        ds = xr.open_dataset(path)

        print('Comienza la extraccion de variables')

        #Extraigo el array de Total Precipitation
        var = ds.tp.values

        #Extrae indices de steps
        idx_steps = extrae_tiempos(ds)

        #Extraigo latitudes y longitudes

        lat = ds.tp.latitude.values
        lon = ds.tp.longitude.values

        #Cerramos dataset
        ds.close()

        print('Se extrajo correctamente las variables del file: ',file)

        #----SUBSET
        
        #latitudes
        lat_index = np.flatnonzero((lat <end_lat) & (lat > ini_lat))
        lat = lat[lat_index]

        #longitudes
        lon_index = np.flatnonzero((lon > ini_lon) & (lon < end_lon))

        lon = lon[lon_index]
        
        #Tiempos para el dia N  
        row = lat.shape[0]
        col = lon.shape[0]

        print('Comienza la creacion de las 10 matrices de pp acumulada para:',file)
        
        for dia in range(idx_steps.shape[0]):

            #Inicializo matriz de pp acumulada
            pp = np.zeros([row,col])

            #Selecciono los indices de steps del dia N
            DiaN = idx_steps[dia,1:]

            name_file = f'{idx_steps[dia, 0]}' 

            print(f'Leyendo archivo {name_file}')

            #Genero una matriz que almacena la precipitacion acumulada
            #por dia
            for tiempo in DiaN:
                pp = np.round(var[tiempo,lat_index[0]:lat_index[-1]+1,lon_index[0]:lon_index[-1]+1] + pp,3)
            
            print('Matrices del file ',file,' generadas correctamente')

            # Ruta completa del archivo donde guardar los datos
            out_path = f'/home/fernando.huaranca/test_forecast/output_matrices/{name_file}.npz'


            # Guardar los arreglos en el archivo

            np.savez(out_path,pp_daily = pp, latitudes = lat,longitudes = lon,name = name_file)

            print('Finalizado')

    except Exception as e:
        print(f'Error al procesar el archivo {file}: {str(e)}')
        fallidos.append(file)
        # Aquí puedes almacenar el nombre del archivo con errores en un registro si es necesario.



print('Proceso finalizado')

print('Lista de Archivos fallidos')
print('Cantidad: ',len(fallidos))
print(fallidos)
# Out:
# ['apcp_sfc_2000043000_c00.grib2']
# Lista de archivos cargada
# Leyendo archivo:  apcp_sfc_2000043000_c00.grib2
# Comienza la extraccion de variables
# Se extrajo correctamente las variables del file:  apcp_sfc_2000043000_c00.grib2
# Comienza la creacion de las 10 matrices de pp acumulada para: apcp_sfc_2000043000_c00.grib2
# Leyendo archivo 30-04-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 01-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 02-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 03-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 04-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 05-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 06-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 07-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 08-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Leyendo archivo 09-05-2000
# Matrices del file  apcp_sfc_2000043000_c00.grib2  generadas correctamente
# Finalizado
# Proceso finalizado
# Lista de Archivos fallidos
# Cantidad:  0
# []
